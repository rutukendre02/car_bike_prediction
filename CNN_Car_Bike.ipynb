# %%
import tensorflow
import cv2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, AveragePooling2D, Flatten, MaxPooling2D


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Image preprocessing

# %%
image_size = (224, 224)
data_generator = ImageDataGenerator(rescale = 1/255, validation_split = 0.2)

train_data_generator = data_generator.flow_from_directory("car_bike_data/", target_size = image_size, batch_size = 32,
                                                         class_mode = "binary", subset = "training")

val_data_generator = data_generator.flow_from_directory("car_bike_data/", target_size = image_size, batch_size = 32,
                                                         class_mode = "binary", subset = "validation")
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %% [markdown]
# ### Model Building

# %%
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = (3,3), strides = (1,1), activation = "relu",
                input_shape = image_size + (3,)))
model.add(AveragePooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(units = 16, activation = "relu"))
model.add(Dense(units = 1, activation = "sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d (AveragePooling2D) │ (None, 111, 111, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 197136)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │       3,154,192 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history = model.fit(train_data_generator, validation_data = val_data_generator, epochs = 20, verbose = 1)
# Out:
# Epoch 1/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 67s 653ms/step - accuracy: 0.5044 - loss: 0.8825 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 2/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 246ms/step - accuracy: 0.5000 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 3/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 310ms/step - accuracy: 0.4825 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 4/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 281ms/step - accuracy: 0.5000 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 5/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 286ms/step - accuracy: 0.5000 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 6/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 284ms/step - accuracy: 0.4900 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 7/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 304ms/step - accuracy: 0.4944 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 8/20
# ...

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3,3), strides = (1,1), activation = "relu",
                input_shape = image_size + (3,)))
model.add(AveragePooling2D(pool_size = (2,2)))

model.add(Conv2D(filters = 16, kernel_size = (3,3), strides = (1,1), activation = "relu",
                input_shape = image_size + (3,)))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Flatten())
model.add(Dense(units = 16, activation = "relu"))
model.add(Dense(units = 1, activation = "sigmoid"))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)                    │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_1                  │ (None, 111, 111, 32)        │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 109, 109, 16)        │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history = model.fit(train_data_generator, validation_data = val_data_generator, epochs = 10, verbose = 1)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 44s 426ms/step - accuracy: 0.8112 - loss: 0.4098 - val_accuracy: 0.8338 - val_loss: 0.4090
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 428ms/step - accuracy: 0.9334 - loss: 0.1861 - val_accuracy: 0.8775 - val_loss: 0.3256
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 403ms/step - accuracy: 0.9706 - loss: 0.0893 - val_accuracy: 0.8938 - val_loss: 0.2899
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 383ms/step - accuracy: 0.9887 - loss: 0.0366 - val_accuracy: 0.8975 - val_loss: 0.3026
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 379ms/step - accuracy: 0.9994 - loss: 0.0089 - val_accuracy: 0.8913 - val_loss: 0.3576
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 431ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8813 - val_loss: 0.4326
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 44s 436ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8863 - val_loss: 0.4617
# Epoch 8/10
# ...

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation="relu",
                 input_shape=(224,224,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(64, activation="relu"))

model.add(Dense(1, activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)                    │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history = model.fit(train_data_generator, validation_data = val_data_generator, epochs = 15, verbose = 1)
# Out:
# Epoch 1/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 86s 833ms/step - accuracy: 0.5866 - loss: 0.9407 - val_accuracy: 0.8112 - val_loss: 0.5707
# Epoch 2/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 85s 848ms/step - accuracy: 0.8472 - loss: 0.4808 - val_accuracy: 0.8700 - val_loss: 0.4766
# Epoch 3/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 83s 828ms/step - accuracy: 0.9144 - loss: 0.3981 - val_accuracy: 0.8500 - val_loss: 0.3467
# Epoch 4/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 81s 815ms/step - accuracy: 0.9347 - loss: 0.1761 - val_accuracy: 0.8900 - val_loss: 0.2619
# Epoch 5/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 86s 859ms/step - accuracy: 0.9744 - loss: 0.0817 - val_accuracy: 0.8913 - val_loss: 0.2469
# Epoch 6/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 88s 882ms/step - accuracy: 0.9916 - loss: 0.0337 - val_accuracy: 0.8838 - val_loss: 0.3114
# Epoch 7/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 84s 844ms/step - accuracy: 0.9978 - loss: 0.0135 - val_accuracy: 0.8975 - val_loss: 0.3370
# Epoch 8/15
# ...

# %% [markdown]
# ### Testing

# %%
image_path = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (3).jpeg"
img = image.load_img(image_path,target_size=(224,224))
image_array = image.img_to_array(img)/255

# %%
test_array = image_array.reshape(1,224,224,3)

# %%
pred_prob = model.predict(test_array)[0,0]
pred_prob
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# np.float32(0.99999994)

# %%
print(train_data_generator.class_indices)
# Out:
# {'Bike': 0, 'Car': 1}

# %%
if pred_prob > 0.5:
    print("Bike")
else:
    print("Car")
# Out:
# Bike

# %%
image_path = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (7).jpg"
img = image.load_img(image_path,target_size=(224,224))
image_array = image.img_to_array(img)/255

# %%
def predict_class(image_path):
    img = image.load_img(image_path, target_size = image_size)
    image_array = image.img_to_array(img)/255
    test_array = image_array.reshape(1,224,224,3)
    pred_prob = model.predict(test_array)[0,0]
    print("pred_prob :", pred_prob)
    pred_class = "car" if pred_prob >= 0.5 else "bike"
    print("image_path :", image_path)
    print("predicted_class is :", pred_class)

# %%
image_path1 = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (9).jpg"
predict_class(image_path1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# pred_prob : 0.9999978
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (9).jpg
# predicted_class is : car

# %%
image_path2 = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (5).jpg"
predict_class(image_path2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# pred_prob : 4.9417426e-06
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (5).jpg
# predicted_class is : bike

# %%
image_path4 = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (8).jpg"
image_path5 = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (137).jpeg"
image_path6 = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (42).jpg"
image_path7 = r"E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (7).jpeg"

# %%
print(predict_class(image_path4))
print(predict_class(image_path5))
print(predict_class(image_path6))
print(predict_class(image_path7))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# pred_prob : 4.595926e-06
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (8).jpg
# predicted_class is : bike
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# pred_prob : 0.9997369
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (137).jpeg
# predicted_class is : car
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# pred_prob : 1.0
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (42).jpg
# predicted_class is : car
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# pred_prob : 1.212115e-07
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (7).jpeg
# predicted_class is : bike
# None

# %%
model.save("car_bike_classifier.keras")

# %%
print(predict_class(image_path4))
print(predict_class(image_path5))
print(predict_class(image_path6))
print(predict_class(image_path7))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# pred_prob : 0.41430292
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (8).jpg
# predicted_class is : bike
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# pred_prob : 0.45619938
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (137).jpeg
# predicted_class is : bike
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# pred_prob : 0.44374123
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Car\Car (42).jpg
# predicted_class is : bike
# None
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# pred_prob : 0.410236
# image_path : E:\Rutuja_datascience_2026\CNN_CAR_BIKE\Car_Bike_Data\Bike\Bike (7).jpeg
# predicted_class is : bike
# None
